# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from botocore.client import Config
import ibm_boto3
import types 

#import data 

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_4d0075b4358a4c1fba0c1e30f76dff9f = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='YouCantSeeMe',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_4d0075b4358a4c1fba0c1e30f76dff9f.get_object(Bucket='edx1-donotdelete-pr-fq7gf43ryr0vfp',Key='BK.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body , low_memory = False)

df_data_1 = df_data_1[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 
'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

df_data_1 = df_data_1.dropna()


body = client_4d0075b4358a4c1fba0c1e30f76dff9f.get_object(Bucket='edx1-donotdelete-pr-fq7gf43ryr0vfp',Key='BX.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
    
df_data_1.head()
# Out:
#                Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  \
# 1        10 JAY STREET    163894      195.0      8.33      2.0       6.5
# 2        1 JOHN STREET    102534        0.0      0.00      2.0       0.0
# 3           JAY STREET         0        0.0      0.00      2.0       0.0
# 6  135 MARSHALL STREET         0        0.0      0.00      2.0       0.0
# 8      1 HUDSON AVENUE         0        0.0      0.00      2.0       0.0
#
#     Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  \
# 1    50    19682    207.25         1       10.0      147505        0
# 2  7501        0      0.00         1       12.0           0    97848
# 3     1   387060    469.00        15        0.0           0        0
# 6     1        0    346.00         4        0.0           0        0
# 8     1   323307    657.00        15        0.0           0        0
#
#    ResidFAR  RetailArea  YearBuilt  YearAlter1  ZipCode    YCoord    XCoord
# ...

# %%
body = client_4d0075b4358a4c1fba0c1e30f76dff9f.get_object(Bucket='edx1-donotdelete-pr-fq7gf43ryr0vfp',Key='BK.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body, low_memory = False)

df_data_2 = df_data_2[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 
'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

df_data_2 = df_data_2.dropna()

df_data_2.head()
# Out:
#                Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  \
# 1             2 STREET         0        0.0      0.00      0.0      10.0
# 2       1-50 51 AVENUE    136108      249.0      4.07      0.0      10.0
# 8             2 STREET         0        0.0      0.00      0.0      10.0
# 9             2 STREET         0        0.0      0.00      0.0      10.0
# 12  1-55 BORDEN AVENUE    228309       70.0     18.87      0.0      10.0
#
#      Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  \
# 1      3    21139    110.00         1        0.0           0        0
# 2      8    33454    184.48         1        5.0           0        0
# 8     50    64242    336.76         0        0.0           0        0
# 9     60   110906    340.92         0        0.0           0        0
# 12  7501    12100    110.00         2       32.0           0   225416
#
#     ResidFAR  RetailArea  YearBuilt  YearAlter1  ZipCode    YCoord    XCoord
# ...

# %%
body = client_4d0075b4358a4c1fba0c1e30f76dff9f.get_object(Bucket='edx1-donotdelete-pr-fq7gf43ryr0vfp',Key='MN.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body, low_memory= False)

df_data_3 = df_data_3[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 
'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

df_data_3 = df_data_3.dropna()

df_data_3.head()
# Out:
#               Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  \
# 0  1 GOVERNORS ISLAND   2725731        0.0      0.35      0.0       1.0   10
# 1    1 LIBERTY ISLAND    541886        0.0      1.00      0.0       1.0  101
# 2      1 ELLIS ISLAND    603130        0.0      0.22      0.0       1.0  201
# 5      4 SOUTH STREET    280000      210.0      1.34      2.0       6.5    1
# 6     10 SOUTH STREET    158197      270.0      0.83      3.4      10.0    2
#
#    LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# 0  7736692      0.00       159        0.0           0        0       0.6
# 1   541886   1046.00        11        0.0           0        0       0.6
# 2  2764190      0.00        13        0.0           0        0       0.6
# 5   209215    564.84         2        5.0           0        0       0.0
# 6   191502    555.84         1        5.0           0        0      10.0
#
# ...

# %%
body = client_4d0075b4358a4c1fba0c1e30f76dff9f.get_object(Bucket='edx1-donotdelete-pr-fq7gf43ryr0vfp',Key='QN.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_4 = pd.read_csv(body, low_memory= False)


df_data_4 = df_data_4[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 
'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

df_data_4 = df_data_4.dropna()

df_data_4.head()
# Out:
#                Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  \
# 1             2 STREET         0        0.0      0.00      0.0      10.0
# 2       1-50 51 AVENUE    136108      249.0      4.07      0.0      10.0
# 8             2 STREET         0        0.0      0.00      0.0      10.0
# 9             2 STREET         0        0.0      0.00      0.0      10.0
# 12  1-55 BORDEN AVENUE    228309       70.0     18.87      0.0      10.0
#
#      Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  \
# 1      3    21139    110.00         1        0.0           0        0
# 2      8    33454    184.48         1        5.0           0        0
# 8     50    64242    336.76         0        0.0           0        0
# 9     60   110906    340.92         0        0.0           0        0
# 12  7501    12100    110.00         2       32.0           0   225416
#
#     ResidFAR  RetailArea  YearBuilt  YearAlter1  ZipCode    YCoord    XCoord
# ...

# %%
body = client_4d0075b4358a4c1fba0c1e30f76dff9f.get_object(Bucket='edx1-donotdelete-pr-fq7gf43ryr0vfp',Key='SI.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_5 = pd.read_csv(body)

df_data_5 = df_data_5[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 
'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 
'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]

df_data_5 = df_data_5.dropna()

df_data_5.head()
# Out:
#              Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  Lot  \
# 0     139 BAY STREET     18965       50.0      3.32      3.4       4.8   10
# 6      65 BAY STREET     10600       41.0      2.30      3.4       4.8   51
# 7      45 BAY STREET     34800      100.0      2.45      3.4       4.8   55
# 8       5 BAY STREET     34941       41.0      0.10      3.4       4.8   60
# 9  150 THE PROMENADE      2700       61.0      0.02      3.4       4.8   65
#
#    LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# 0     5716      84.0         1        4.0           0        0      2.43
# 6     4600      70.0         1        3.0        9400        0      2.43
# 7    14200     234.0         1        2.0       34800        0      2.43
# 8   334565     234.0         4        4.0           0        0      2.43
# 9   121810       0.0         2        3.0           0        0      2.43
#
#    RetailArea  YearBuilt  YearAlter1  ZipCode    YCoord    XCoord
# ...

# %%
#import the big ass 311 dataset
url = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$limit=100000000&Agency=HPD&$select=created_date,unique_key,complaint_type,incident_zip,incident_address,street_name,address_type,city,resolution_description,borough,latitude,longitude,closed_date,location_type,status"

#Assign dataframe and parse the dates
df = pd.read_csv(url , parse_dates=['created_date'])

# Select only rows with Hot Water
df_complaint = df.loc[df['complaint_type']=='HEAT/HOT WATER'].dropna()

df_complaint.head()
# Out:
#            created_date  unique_key  complaint_type  incident_zip  \
# 34  2019-12-29 04:32:53    45268924  HEAT/HOT WATER       11230.0
# 158 2019-12-29 08:39:28    45267702  HEAT/HOT WATER       10463.0
# 168 2019-12-29 09:40:54    45265795  HEAT/HOT WATER       10459.0
# 174 2019-12-29 13:48:20    45266314  HEAT/HOT WATER       10463.0
# 263 2019-12-29 05:54:14    45269483  HEAT/HOT WATER       10029.0
#
#          incident_address       street_name address_type      city  \
# 34   788 EAST   10 STREET  EAST   10 STREET      ADDRESS  BROOKLYN
# 158     3816 REVIEW PLACE      REVIEW PLACE      ADDRESS     BRONX
# 168    1094 BRYANT AVENUE     BRYANT AVENUE      ADDRESS     BRONX
# 174     3816 REVIEW PLACE      REVIEW PLACE      ADDRESS     BRONX
# 263      1265 PARK AVENUE       PARK AVENUE      ADDRESS  NEW YORK
#
#                                 resolution_description    borough   latitude  \
# 34   The Department of Housing Preservation and Dev...   BROOKLYN  40.630019
# ...

# %%
dfpluto = [df_data_1, df_data_2, df_data_3, df_data_4, df_data_5]

df_pluto = pd.concat(dfpluto)

df_pluto.index = range(len(df_pluto.index))

df_pluto.shape
# Out:
# (1064785, 20)

# %%
print(df_complaint.columns)
print(df_pluto.columns)
# Out:
# Index(['created_date', 'unique_key', 'complaint_type', 'incident_zip',
#        'incident_address', 'street_name', 'address_type', 'city',
#        'resolution_description', 'borough', 'latitude', 'longitude',
#        'closed_date', 'location_type', 'status'],
#       dtype='object')
# Index(['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR',
#        'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'NumFloors', 'OfficeArea',
#        'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1',
#        'ZipCode', 'YCoord', 'XCoord'],
#       dtype='object')

# %%
df_pluto2 = df_pluto[['Address']].isin(df_complaint['incident_address'].unique())
print(df_pluto2['Address'].sum())
df_pluto2 = (df_pluto2['Address'])*1
df_pluto2.dtypes
# Out:
# 75267
# dtype('int64')

# %%
df_pluto.loc[:,'target'] = df_pluto2
df_pluto.head()
# Out:
#                Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  \
# 0        10 JAY STREET    163894      195.0      8.33      2.0       6.5
# 1        1 JOHN STREET    102534        0.0      0.00      2.0       0.0
# 2           JAY STREET         0        0.0      0.00      2.0       0.0
# 3  135 MARSHALL STREET         0        0.0      0.00      2.0       0.0
# 4      1 HUDSON AVENUE         0        0.0      0.00      2.0       0.0
#
#     Lot  LotArea  LotDepth  NumBldgs  ...  OfficeArea  ResArea  ResidFAR  \
# 0    50    19682    207.25         1  ...      147505        0       5.4
# 1  7501        0      0.00         1  ...           0    97848       0.0
# 2     1   387060    469.00        15  ...           0        0       0.0
# 3     1        0    346.00         4  ...           0        0       0.0
# 4     1   323307    657.00        15  ...           0        0       0.0
#
#    RetailArea  YearBuilt  YearAlter1  ZipCode    YCoord    XCoord  target
# ...

# %%
import seaborn as sns

# using Pearson correlation
plt.figure(figsize=(15,15))
cor = df_pluto.corr()
sns.heatmap(cor, annot = True, cmap=plt.cm.Reds)
plt.show()

# %%
target = abs(cor["target"])
#Selecting highly correlated features.
relevantcharac = target[cor_target>0.15]
relevantcharac
# Out:
# FacilFAR     0.193225
# NumFloors    0.191761
# ResidFAR     0.208223
# target       1.000000
# Name: target, dtype: float64

# %%
#The Above have the most correlation to Hot Water Complaints.
